# %% [markdown]
# # Visualização de dados

# %% [markdown]
# 1. Faça o download do arquivo **sitka_weather_2014.csv**, com dados metereológicos da cidade de sitka no Alaska, que está armazenado no endereço **https://raw.githubusercontent.com/ehmatthes/pcc/master/chapter_16/sitka_weather_2014.csv**.

# %%
import matplotlib.pyplot as plt
import pandas as pd
from urllib.request import urlretrieve

# %%
url = 'https://raw.githubusercontent.com/ehmatthes/pcc/master/chapter_16/sitka_weather_2014.csv'
urlretrieve(url, 'datasets/sitka_weather_2014.csv')
# Out:
# ('datasets/sitka_weather_2014.csv', <http.client.HTTPMessage at 0x11e8127f0>)

# %% [markdown]
# 2. Verifique a estrutura do arquivo **sitka_weather_2014.csv** com os comandos **head** and **tail** do Linux.

# %%
arquivo = 'datasets/sitka_weather_2014.csv'
# !head -n 5 $arquivo
# Out:
# AKST,Max TemperatureF,Mean TemperatureF,Min TemperatureF,Max Dew PointF,MeanDew PointF,Min DewpointF,Max Humidity, Mean Humidity, Min Humidity, Max Sea Level PressureIn, Mean Sea Level PressureIn, Min Sea Level PressureIn, Max VisibilityMiles, Mean VisibilityMiles, Min VisibilityMiles, Max Wind SpeedMPH, Mean Wind SpeedMPH, Max Gust SpeedMPH,PrecipitationIn, CloudCover, Events, WindDirDegrees
# 2014-1-1,46,42,37,40,38,36,97,86,76,29.95,29.77,29.57,10,8,2,25,14,36,0.69,8,Rain,138
# 2014-1-2,41,38,35,38,35,32,97,89,76,30.09,29.90,29.81,10,9,4,14,7,22,0.34,8,Rain,92
# 2014-1-3,39,36,34,38,36,33,100,97,93,30.43,30.32,30.10,10,9,2,8,3,,0.02,7,Rain,102
# 2014-1-4,43,38,34,35,33,31,97,82,62,30.43,30.32,30.20,10,10,10,20,6,25,0.00,6,Rain,107

# %%
# !tail -n 5 $arquivo
# Out:
# 2014-12-18,45,43,41,33,30,27,67,60,55,29.52,29.31,29.19,10,10,10,21,14,30,0.00,7,Rain,112
# 2014-12-19,46,44,42,35,33,30,74,65,60,29.26,29.16,29.01,10,10,10,21,15,31,0.01,6,Rain,117
# 2014-12-20,46,44,41,39,36,33,93,72,59,29.13,28.95,28.81,10,10,7,21,15,30,0.07,8,Rain,117
# 2014-12-21,42,40,37,40,38,37,100,94,85,29.79,29.44,29.14,10,10,9,10,6,,0.11,7,Rain,85
# 2014-12-22,45,42,39,41,38,32,97,85,67,30.10,29.97,29.71,10,9,4,23,8,22,0.15,7,Rain,130

# %% [markdown]
# 3. Importe o arquivo **sitka_weather_2014.csv** para o dataframe **sitkas**. Mostre as colunas do dataframe **sitkas**.

# %%
sitkas = pd.read_csv(arquivo, sep=',', parse_dates=['AKST'])
sitkas.columns
# Out:
# Index(['AKST', 'Max TemperatureF', 'Mean TemperatureF', 'Min TemperatureF',
#        'Max Dew PointF', 'MeanDew PointF', 'Min DewpointF', 'Max Humidity',
#        ' Mean Humidity', ' Min Humidity', ' Max Sea Level PressureIn',
#        ' Mean Sea Level PressureIn', ' Min Sea Level PressureIn',
#        ' Max VisibilityMiles', ' Mean VisibilityMiles', ' Min VisibilityMiles',
#        ' Max Wind SpeedMPH', ' Mean Wind SpeedMPH', ' Max Gust SpeedMPH',
#        'PrecipitationIn', ' CloudCover', ' Events', ' WindDirDegrees'],
#       dtype='object')

# %% [markdown]
# 4. Mostre as primeiras linhas do dataframe **sitkas**.

# %%
sitkas.head()
# Out:
#         AKST  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0 2014-01-01                46                 42                37
# 1 2014-01-02                41                 38                35
# 2 2014-01-03                39                 36                34
# 3 2014-01-04                43                 38                34
# 4 2014-01-05                44                 42                41
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0              40              38             36            97
# 1              38              35             32            97
# 2              38              36             33           100
# 3              35              33             31            97
# 4              42              36             32            97
#
#     Mean Humidity   Min Humidity       ...          Max VisibilityMiles  \
# 0              86             76       ...                           10
# ...

# %% [markdown]
# 5. Plote em um gráfico de linhas as temperaturas máximas(**Max TemperatureF**) diárias no dataframe **sitkas**. As linhas do gráfico deverão ser vermelhas.

# %%
sitkas.plot(x='AKST', y='Max TemperatureF', color='red')

# %% [markdown]
# 6. Plote gráfico anterior novamente com o tamanho de 20x10.

# %%
plt.figure(figsize=(20, 10))
plt.plot(sitkas['AKST'], sitkas['Max TemperatureF'], color='red')

# %% [markdown]
# 7. Plote o gráfico anterior com o título **Temperaturas Máximas Diárias, Julho 2014**. O tamanho de fonte  do gráfico deverá ser 24 (**fontsize=24**).

# %%
plt.figure(figsize=(20, 10))
plt.title('Temperaturas Máximas Diárias, 2014', fontsize=24)
plt.plot(sitkas['AKST'], sitkas['Max TemperatureF'], color='red')

# %% [markdown]
# 8. Plote o gráfico anterior com o título no eixo igual a **Temperatura (F)**. O tamanho da fonte do título no eixo y do gráfico deverá ser 16 (**fontsize=16**).

# %%
plt.figure(figsize=(20, 10))
plt.plot(sitkas['AKST'], sitkas['Max TemperatureF'], color='red')
plt.title('Temperaturas Máximas Diárias, 2014', fontsize=24)
plt.ylabel("Temperatura (F)", fontsize=16)
# Out:
# Text(0, 0.5, 'Temperatura (F)')

# %% [markdown]
# 9. Plote o gráfico anterior aumentando o tamanho da fonte os 'labels' dos eixos x e y para 16.

# %%
plt.figure(dpi=128, figsize=(20, 10))
plt.plot(sitkas['AKST'], sitkas['Max TemperatureF'], color='red')
plt.title('Temperaturas Máximas Diárias, 2014', fontsize=24)
plt.ylabel("Temperatura (F)", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=16)

# %% [markdown]
# 10. Plote em um gráfico de linhas as temperaturas mínimas(**Min TemperatureF**) diárias no dataframe **sitkas**. As linhas do gráfico deverão ser azuis.

# %%
plt.figure(dpi=128, figsize=(20, 10))
plt.plot(sitkas['AKST'], sitkas['Max TemperatureF'], color='red')
plt.plot(sitkas['AKST'], sitkas['Min TemperatureF'], color='blue')
plt.title('Temperaturas Máximas e Minímas Diárias, 2014', fontsize=24)
plt.ylabel("Temperatura (F)", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=16)

# %% [markdown]
# 11. Plote o gráfico anterior alterando os limites do eixo y para 0 e 80 utlizando o método **ylim()**.

# %%
plt.figure(dpi=128, figsize=(20, 10))
plt.plot(sitkas['AKST'], sitkas['Max TemperatureF'], color='red')
plt.plot(sitkas['AKST'], sitkas['Min TemperatureF'], color='blue')
plt.title('Temperaturas Máximas e Minímas Diárias, 2014', fontsize=24)
plt.ylabel("Temperatura (F)", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.ylim(0, 80)
# Out:
# (0, 80)

# %% [markdown]
# 12. Plote o gráfico anterior colocando a legenda no canto inferior direito utilizando o método **legend()**.

# %%
plt.figure(dpi=128, figsize=(20, 10))
plt.plot(sitkas['AKST'], sitkas['Max TemperatureF'], color='red')
plt.plot(sitkas['AKST'], sitkas['Min TemperatureF'], color='blue')
plt.title('Temperaturas Máximas e Minímas Diárias, 2014', fontsize=24)
plt.ylabel("Temperatura (F)", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.ylim(0, 80)
plt.legend(loc='lower right')

# %% [markdown]
# 14. Plote o estilo do gráfico para o tema **fivethirtyeight** utilizando o método **plt.style.use()**.

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(20, 10))
plt.plot(sitkas['AKST'], sitkas['Max TemperatureF'], color='red')
plt.plot(sitkas['AKST'], sitkas['Min TemperatureF'], color='blue')
plt.title('Temperaturas Máximas e Minímas Diárias, 2014', fontsize=24)
plt.ylabel("Temperatura (F)", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.ylim(0, 80)
plt.legend(loc='lower right')

# %% [markdown]
# 15. Salve o gráfico anterior em um arquivo **.png** utlizando o método **savefig**.

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(20, 10))
plt.plot(sitkas['AKST'], sitkas['Max TemperatureF'], color='red')
plt.plot(sitkas['AKST'], sitkas['Min TemperatureF'], color='blue')
plt.title('Temperaturas Máximas e Minímas Diárias, 2014', fontsize=24)
plt.ylabel("Temperatura (F)", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.ylim(0, 80)
plt.legend(loc='lower right')
plt.savefig('temparaturas_max_min_2014.png')

# %% [markdown]
# 16. Plote os gráficos de temperaturas máximas(**Max TemperatureF**) e mínimas (**Min TemperatureF**) diárias no dataframe **sitkas** utilizando o método **subplot**.

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(20, 10))
plt.subplot(1, 2, 1)
plt.plot(sitkas['AKST'], sitkas['Max TemperatureF'], color='red')
plt.title('Temperaturas Máx Diárias, 2014')
plt.subplot(1, 2, 2)
plt.plot(sitkas['AKST'], sitkas['Min TemperatureF'], color='blue')
plt.title('Temperaturas Min Diárias, 2014')
plt.tight_layout()
plt.savefig('temparaturas_max_min_2014.png')
